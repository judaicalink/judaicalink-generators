# %% [markdown]
# # GND Names lookup

# %%
import rdflib
import SPARQLWrapper as sw

prefixes = []
prefixes.append(('skos', 'http://www.w3.org/2004/02/skos/core#'))
prefixes.append(('gndo', 'http://d-nb.info/standards/elementset/gnd#'))

sparql = sw.SPARQLWrapper2("http://zbw.eu/beta/sparql/gnd/query")

def get_prefixes():
    return "\n".join(["PREFIX {}: <{}>".format(prefix, url) for prefix, url in prefixes])

def sparql_query(q):
    q = get_prefixes() + "\n\n" + q
    sparql.setQuery(q)
    return sparql.query()

# %%
res = sparql_query('''
SELECT DISTINCT ?forename ?forename2 WHERE {
        # ?s a gndo:UndifferentiatedPerson .
        # ?s gndo:preferredNameEntityForThePerson ?pne .
        # ?pne gndo:forename ?forename .
            # ?s gndo:variantNameEntityForThePerson ?vne .
            # ?vne gndo:forename ?forename2 .
  FILTER regex(str(?forename), "^[^ ]+$")
  FILTER regex(str(?forename2), "^[^ ]+$")
  FILTER regex(str(?forename2), "^[^.]+$")
  FILTER regex(str(?forename), "^[^.]+$")
    } LIMIT 100

''')

# %%
len(res.bindings)
# Out:
# 100

# %%
res.bindings
# Out:
# [{'forename': Value(literal:'Ludwig'), 'forename2': Value(literal:'Ludwig')},
#  {'forename': Value(literal:'Paul'), 'forename2': Value(literal:'Paulus')},
#  {'forename': Value(literal:'Dirk'), 'forename2': Value(literal:'Didericus')},
#  {'forename': Value(literal:'Heinrich'),
#   'forename2': Value(literal:'Heinrich')},
#  {'forename': Value(literal:'Heinrich'),
#   'forename2': Value(literal:'Henricus')},
#  {'forename': Value(literal:'Heimann'), 'forename2': Value(literal:'Hermann')},
#  {'forename': Value(literal:'Barthélemy'),
#   'forename2': Value(literal:'Bartholomaeus')},
#  {'forename': Value(literal:'Barthélemy'),
#   'forename2': Value(literal:'Barptolomaeus')},
#  {'forename': Value(literal:'Barthélemy'),
#   'forename2': Value(literal:'Bartholomé')},
#  {'forename': Value(literal:'John'), 'forename2': Value(literal:'Johann')},
#  {'forename': Value(literal:'Stefano'), 'forename2': Value(literal:'Stefano')},
#  {'forename': Value(literal:'Georgius'), 'forename2': Value(literal:'Georg')},
#  {'forename': Value(literal:'Oratio'), 'forename2': Value(literal:'Horatius')},
#  {'forename': Value(literal:'Gaspard'), 'forename2': Value(literal:'Gaspard')},
#  {'forename': Value(literal:'Jacob'), 'forename2': Value(literal:'Jakob')},
#  {'forename': Value(literal:'Joachim'),
#   'forename2': Value(literal:'Joachimus')},
#  {'forename': Value(literal:'Miguel'), 'forename2': Value(literal:'Aly')},
#  {'forename': Value(literal:'Miguel'), 'forename2': Value(literal:'ʿAli')},
#  {'forename': Value(literal:'Miguel'), 'forename2': Value(literal:'Michel')},
#  {'forename': Value(literal:'Miguel'),
#   'forename2': Value(literal:'Abulcacim')},
#  {'forename': Value(literal:'Miguel'), 'forename2': Value(literal:'Miguel')},
#  {'forename': Value(literal:'John'), 'forename2': Value(literal:'Johan')},
#  {'forename': Value(literal:'Adriaan'),
#   'forename2': Value(literal:'Adrianus')},
#  {'forename': Value(literal:'Francesco'),
#   'forename2': Value(literal:'Franciscus')},
#  {'forename': Value(literal:'Louis'),
#   'forename2': Value(literal:'Jean-Louis')},
#  {'forename': Value(literal:'Robert'), 'forename2': Value(literal:'Rob')},
#  {'forename': Value(literal:'Camillo'), 'forename2': Value(literal:'Camillo')},
#  {'forename': Value(literal:'Domingo'),
#   'forename2': Value(literal:'Dominicus')},
#  {'forename': Value(literal:'Gabriel'), 'forename2': Value(literal:'Gabriel')},
#  {'forename': Value(literal:'Gustaf'), 'forename2': Value(literal:'Gustav')},
#  {'forename': Value(literal:'Alfonso'), 'forename2': Value(literal:'Alfonso')},
#  {'forename': Value(literal:'Mateo'), 'forename2': Value(literal:'Mateo')},
#  {'forename': Value(literal:'Mateo'), 'forename2': Value(literal:'Matthaeus')},
#  {'forename': Value(literal:'Mateo'), 'forename2': Value(literal:'Matthieus')},
#  {'forename': Value(literal:'William'),
#   'forename2': Value(literal:'Gulielmus')},
#  {'forename': Value(literal:'Bartholomeo'),
#   'forename2': Value(literal:'Bartolomeo')},
#  {'forename': Value(literal:'Bartholomeo'),
#   'forename2': Value(literal:'Bartholomeo')},
#  {'forename': Value(literal:'Bartholomeo'),
#   'forename2': Value(literal:'Bartholomaeus')},
#  {'forename': Value(literal:'Nicolaus'),
#   'forename2': Value(literal:'Nicolaus')},
#  {'forename': Value(literal:'Nicolaus'),
#   'forename2': Value(literal:'Nikolaus')},
#  {'forename': Value(literal:'Johann'), 'forename2': Value(literal:'Johannes')},
#  {'forename': Value(literal:'Gilles'), 'forename2': Value(literal:'Aegidius')},
#  {'forename': Value(literal:'Annibale'),
#   'forename2': Value(literal:'Hannibal')},
#  {'forename': Value(literal:'Annibale'),
#   'forename2': Value(literal:'Annibal')},
#  {'forename': Value(literal:'Henri'), 'forename2': Value(literal:'Henri')},
#  {'forename': Value(literal:'Norbert'),
#   'forename2': Value(literal:'Norbertus')},
#  {'forename': Value(literal:'Francesco'),
#   'forename2': Value(literal:'Oresbio')},
#  {'forename': Value(literal:'Ermolao'),
#   'forename2': Value(literal:'Hermolaus')},
#  {'forename': Value(literal:'Ermolao'), 'forename2': Value(literal:'Almoro')},
#  {'forename': Value(literal:'Affonso'), 'forename2': Value(literal:'Alfonso')},
#  {'forename': Value(literal:'Affonso'), 'forename2': Value(literal:'Afonso')},
#  {'forename': Value(literal:'Ludovicus'), 'forename2': Value(literal:'Luys')},
#  {'forename': Value(literal:'Giovanni'),
#   'forename2': Value(literal:'Giovanni')},
#  {'forename': Value(literal:'Christoph'),
#   'forename2': Value(literal:'Christophorus')},
#  {'forename': Value(literal:'Giuseppe'),
#   'forename2': Value(literal:'Josephus')},
#  {'forename': Value(literal:'Bernardino'),
#   'forename2': Value(literal:'Bernhard')},
#  {'forename': Value(literal:'Benjamin'),
#   'forename2': Value(literal:'Benjaminus')},
#  {'forename': Value(literal:'Dēmētrios'),
#   'forename2': Value(literal:'Démétrius')},
#  {'forename': Value(literal:'Cajetanus'),
#   'forename2': Value(literal:'Cajetan')},
#  {'forename': Value(literal:'Andrea'), 'forename2': Value(literal:'Andreas')},
#  {'forename': Value(literal:'Michael'), 'forename2': Value(literal:'Michael')},
#  {'forename': Value(literal:'Jacob'), 'forename2': Value(literal:'Jacob')},
#  {'forename': Value(literal:'Bernardo'),
#   'forename2': Value(literal:'Bernardus')},
#  {'forename': Value(literal:'Giacinto'),
#   'forename2': Value(literal:'Hyacinthus')},
#  {'forename': Value(literal:'Giulio'), 'forename2': Value(literal:'Julius')},
#  {'forename': Value(literal:'Floridus'),
#   'forename2': Value(literal:'Floridus')},
#  {'forename': Value(literal:'Franciscus'),
#   'forename2': Value(literal:'François')},
#  {'forename': Value(literal:'Gervasius'),
#   'forename2': Value(literal:'Gervasius')},
#  {'forename': Value(literal:'Moritz'), 'forename2': Value(literal:'Moritz')},
#  {'forename': Value(literal:'Moritz'),
#   'forename2': Value(literal:'Mauricius')},
#  {'forename': Value(literal:'Franciscus'),
#   'forename2': Value(literal:'Fransoys')},
#  {'forename': Value(literal:'Nicholas'), 'forename2': Value(literal:'Caleb')},
#  {'forename': Value(literal:'Giovanni'),
#   'forename2': Value(literal:'Johannes')},
#  {'forename': Value(literal:'Vittorio'), 'forename2': Value(literal:'Victor')},
#  {'forename': Value(literal:'Pierre'), 'forename2': Value(literal:'Pierre')},
#  {'forename': Value(literal:'Pierre'), 'forename2': Value(literal:'Petrus')},
#  {'forename': Value(literal:'Guy'), 'forename2': Value(literal:'Gui')},
#  {'forename': Value(literal:'Franz'),
#   'forename2': Value(literal:'Franciscus')},
#  {'forename': Value(literal:'Pierre'), 'forename2': Value(literal:'Peter')},
#  {'forename': Value(literal:'Pierre'), 'forename2': Value(literal:'Petro')},
#  {'forename': Value(literal:'Francisco'),
#   'forename2': Value(literal:'Franciscus')},
#  {'forename': Value(literal:'Sebastiano'),
#   'forename2': Value(literal:'Sebastianus')},
#  {'forename': Value(literal:'Sebastiano'),
#   'forename2': Value(literal:'Sebastinus')},
#  {'forename': Value(literal:'Giacomo'), 'forename2': Value(literal:'Jacobus')},
#  {'forename': Value(literal:'Petrus'), 'forename2': Value(literal:'Pietro')},
#  {'forename': Value(literal:'Bernardino'),
#   'forename2': Value(literal:'Bernardinus')},
#  {'forename': Value(literal:'Bernardino'),
#   'forename2': Value(literal:'Bernardino')},
#  {'forename': Value(literal:'Bernardino'),
#   'forename2': Value(literal:'Bernhardinus')},
#  {'forename': Value(literal:'Augustinus'),
#   'forename2': Value(literal:'Augustinus')},
#  {'forename': Value(literal:'Charles'), 'forename2': Value(literal:'Carolus')},
#  {'forename': Value(literal:'Johann'), 'forename2': Value(literal:'Johann')},
#  {'forename': Value(literal:'Federigo'),
#   'forename2': Value(literal:'Federigo')},
#  {'forename': Value(literal:'Federigo'),
#   'forename2': Value(literal:'Friedrich')},
#  {'forename': Value(literal:'Federigo'),
#   'forename2': Value(literal:'Fridericus')},
#  {'forename': Value(literal:'Offreduccio'),
#   'forename2': Value(literal:'Offredutio')},
#  {'forename': Value(literal:'Lorenzo'),
#   'forename2': Value(literal:'Laurentius')},
#  {'forename': Value(literal:'Mario'), 'forename2': Value(literal:'Marius')},
#  {'forename': Value(literal:'Pedro'), 'forename2': Value(literal:'Petrus')},
#  {'forename': Value(literal:'Antonio'),
#   'forename2': Value(literal:'António')},
#  {'forename': Value(literal:'Luis'), 'forename2': Value(literal:'Ludovicus')}]
